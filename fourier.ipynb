# %%
import os
import numpy as np
from spectral import envi
import json

with open("train_only_labeled.json", "r") as f:
    data = json.load(f)

annotations = data["annotations"]
records = data["records"]
cameras = data["cameras"]
vis_wls = cameras[0]["wavelengths"]
nir_wls = cameras[1]["wavelengths"]

ripeness_mapping = {"unripe": 0, "perfect": 1, "overripe": 2}

X = []
Y = []

for annotation in annotations:
    record = next((r for r in records if r["id"] == annotation["record_id"]), None)
    if record:
        try:
            image = envi.open(
                f"data/{record["files"]["header_file"]}",
                image=f"data/{record["files"]["data_file"]}",
            )
            X.append({"image": image.load(), "camera": record["camera_type"]})
            Y.append(ripeness_mapping[annotation["ripeness_state"]])
        except Exception as e:
            print(f"Error loading image: {e}")

X = np.array(X, dtype=object)
Y = np.array(Y, dtype=int)

print(f"Loaded dataset: {len(X)} samples.")
# Out:
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_01/kiwi_day_01_03_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_01/kiwi_day_01_03_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_01/kiwi_day_01_03_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_01/kiwi_day_01_03_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_01/kiwi_day_01_28_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_01/kiwi_day_01_28_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_01/kiwi_day_01_28_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_01/kiwi_day_01_28_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_02/kiwi_day_02_10_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_02/kiwi_day_02_10_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_02/kiwi_day_02_10_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_02/kiwi_day_02_10_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_02/kiwi_day_02_15_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_02/kiwi_day_02_15_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_02/kiwi_day_02_15_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_02/kiwi_day_02_15_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_02/kiwi_day_02_30_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_02/kiwi_day_02_30_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_02/kiwi_day_02_30_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_02/kiwi_day_02_30_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_02/kiwi_day_02_31_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_02/kiwi_day_02_31_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_02/kiwi_day_02_31_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_02/kiwi_day_02_31_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_02/kiwi_day_02_33_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_02/kiwi_day_02_33_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_02/kiwi_day_02_33_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_02/kiwi_day_02_33_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_03/kiwi_day_03_07_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_03/kiwi_day_03_07_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_03/kiwi_day_03_07_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_03/kiwi_day_03_17_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_03/kiwi_day_03_17_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_03/kiwi_day_03_17_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_03/kiwi_day_03_19_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_03/kiwi_day_03_19_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_03/kiwi_day_03_19_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_03/kiwi_day_03_23_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_03/kiwi_day_03_23_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_03/kiwi_day_03_23_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_03/kiwi_day_03_39_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_03/kiwi_day_03_39_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_03/kiwi_day_03_39_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_04/kiwi_day_04_12_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_04/kiwi_day_04_12_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_04/kiwi_day_04_13_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_04/kiwi_day_04_18_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_04/kiwi_day_04_18_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_04/kiwi_day_04_21_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_04/kiwi_day_04_21_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_04/kiwi_day_04_21_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_04/kiwi_day_04_21_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_04/kiwi_day_04_22_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_04/kiwi_day_04_22_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_04/kiwi_day_04_22_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_04/kiwi_day_04_29_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_04/kiwi_day_04_29_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_04/kiwi_day_04_29_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_05/kiwi_day_05_02_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_05/kiwi_day_05_02_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_05/kiwi_day_05_02_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_05/kiwi_day_05_05_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_05/kiwi_day_05_05_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_05/kiwi_day_05_05_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_05/kiwi_day_05_08_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_05/kiwi_day_05_08_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_05/kiwi_day_05_08_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_05/kiwi_day_05_32_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_05/kiwi_day_05_37_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_05/kiwi_day_05_37_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_05/kiwi_day_05_37_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_05/kiwi_day_05_37_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_06/kiwi_day_06_01_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_06/kiwi_day_06_01_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_06/kiwi_day_06_01_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_06/kiwi_day_06_11_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_06/kiwi_day_06_11_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_06/kiwi_day_06_20_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_06/kiwi_day_06_20_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_06/kiwi_day_06_20_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_06/kiwi_day_06_35_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_06/kiwi_day_06_35_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_06/kiwi_day_06_35_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_06/kiwi_day_06_36_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_06/kiwi_day_06_36_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_06/kiwi_day_06_36_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_06/kiwi_day_06_38_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_06/kiwi_day_06_38_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_06/kiwi_day_06_38_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_07/kiwi_day_07_06_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_07/kiwi_day_07_06_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_07/kiwi_day_07_06_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_07/kiwi_day_07_06_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_07/kiwi_day_07_09_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_07/kiwi_day_07_09_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_07/kiwi_day_07_09_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_07/kiwi_day_07_09_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_07/kiwi_day_07_14_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_07/kiwi_day_07_14_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_07/kiwi_day_07_14_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_07/kiwi_day_07_14_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_07/kiwi_day_07_16_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_07/kiwi_day_07_16_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_07/kiwi_day_07_24_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_07/kiwi_day_07_24_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_08/kiwi_day_08_04_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_08/kiwi_day_08_04_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_08/kiwi_day_08_04_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_09/kiwi_day_09_25_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_09/kiwi_day_09_25_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/NIR/day_09/kiwi_day_09_25_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_09/kiwi_day_09_25_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_10/kiwi_day_10_27_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_10/kiwi_day_10_27_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_01/kiwi_day_m2_01_53_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_01/kiwi_day_m2_01_53_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_01/kiwi_day_m2_01_71_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_02/kiwi_day_m2_02_43_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_02/kiwi_day_m2_02_43_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_02/kiwi_day_m2_02_75_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_02/kiwi_day_m2_02_75_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_02/kiwi_day_m2_02_85_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_02/kiwi_day_m2_02_85_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_03/kiwi_day_m2_03_40_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_03/kiwi_day_m2_03_40_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_03/kiwi_day_m2_03_52_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_03/kiwi_day_m2_03_70_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_03/kiwi_day_m2_03_70_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_03/kiwi_day_m2_03_75_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_03/kiwi_day_m2_03_75_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_03/kiwi_day_m2_03_77_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_03/kiwi_day_m2_03_77_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_04/kiwi_day_m2_04_61_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_04/kiwi_day_m2_04_61_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_04/kiwi_day_m2_04_72_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_04/kiwi_day_m2_04_72_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_04/kiwi_day_m2_04_75_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_04/kiwi_day_m2_04_75_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_04/kiwi_day_m2_04_81_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_04/kiwi_day_m2_04_81_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_04/kiwi_day_m2_04_87_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_05/kiwi_day_m2_05_51_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_05/kiwi_day_m2_05_65_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_05/kiwi_day_m2_05_65_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_05/kiwi_day_m2_05_74_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_05/kiwi_day_m2_05_75_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_05/kiwi_day_m2_05_75_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_06/kiwi_day_m2_06_78_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_06/kiwi_day_m2_06_78_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_06/kiwi_day_m2_06_79_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_06/kiwi_day_m2_06_79_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_06/kiwi_day_m2_06_84_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_06/kiwi_day_m2_06_84_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_06/kiwi_day_m2_06_86_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_06/kiwi_day_m2_06_86_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_07/kiwi_day_m2_07_49_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_07/kiwi_day_m2_07_56_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_07/kiwi_day_m2_07_56_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_07/kiwi_day_m2_07_60_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_07/kiwi_day_m2_07_83_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_07/kiwi_day_m2_07_83_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_08/kiwi_day_m2_08_54_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_08/kiwi_day_m2_08_63_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_08/kiwi_day_m2_08_82_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_08/kiwi_day_m2_08_82_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_09/kiwi_day_m2_09_47_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_09/kiwi_day_m2_09_47_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_09/kiwi_day_m2_09_59_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_09/kiwi_day_m2_09_59_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_09/kiwi_day_m2_09_80_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_09/kiwi_day_m2_09_80_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_10/kiwi_day_m2_10_46_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_10/kiwi_day_m2_10_55_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_10/kiwi_day_m2_10_58_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_10/kiwi_day_m2_10_58_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_11/kiwi_day_m2_11_66_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_11/kiwi_day_m2_11_66_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_11/kiwi_day_m2_11_68_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_11/kiwi_day_m2_11_73_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_12/kiwi_day_m2_12_76_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_13/kiwi_day_m2_13_42_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_13/kiwi_day_m2_13_42_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_13/kiwi_day_m2_13_64_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_13/kiwi_day_m2_13_64_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_14/kiwi_day_m2_14_41_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_14/kiwi_day_m2_14_48_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_14/kiwi_day_m2_14_48_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_14/kiwi_day_m2_14_67_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_14/kiwi_day_m2_14_67_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_15/kiwi_day_m2_15_48_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_15/kiwi_day_m2_15_69_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_16/kiwi_day_m2_16_48_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_16/kiwi_day_m2_16_57_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_17/kiwi_day_m2_17_44_front.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_17/kiwi_day_m2_17_44_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Error loading image: Unable to locate file "data/Kiwi/VIS/day_m2_17/kiwi_day_m2_17_48_back.hdr". If the file exists, use its full path or place its directory in the SPECTRAL_DATA environment variable.
# Loaded dataset: 132 samples.

# %%
import numpy as np


def fourier_features(image):
    """Compute Fourier Transform magnitudes for each pixel's spectral vector."""
    fft_magnitude = np.abs(
        np.fft.fft(image, axis=-1)
    )  # Apply FFT along spectral channels
    return fft_magnitude[:, :, : image.shape[-1] // 2]  # Use only positive frequencies


def fourier_2d_features(image):
    """Compute 2D Fourier Transform for each spectral channel."""
    fft_features = []
    for i in range(image.shape[-1]):  # Iterate through spectral channels
        channel_fft = np.fft.fft2(image[:, :, i])
        fft_magnitude = np.abs(channel_fft)
        fft_features.append(
            fft_magnitude.flatten()
        )  # Flatten to create a feature vector
    return np.concatenate(fft_features)  # Combine all channels


def low_freq_features(fft_magnitude, k=10):
    """Select the first k low-frequency components from FFT features."""
    return fft_magnitude[:, :, :k].flatten()

# %%
X1 = []
Y1 = []

for x, y in zip(X, Y):
    if x["camera"] == "VIS":
        X1.append(x)
        Y1.append(y)

X1 = np.array(X1, dtype=object)
Y1 = np.array(Y1, dtype=int)

print(f"Loaded dataset: {len(X1)} samples.")
# Out:
# Loaded dataset: 92 samples.

# %%
def pad_features(features, fill_value=0):
    """Pad feature vectors to have the same length."""
    max_length = max(len(f) for f in features)
    return np.array(
        [
            np.pad(f, (0, max_length - len(f)), constant_values=fill_value)
            for f in features
        ]
    )


X_padded = [pad_features(image["image"]) for image in X1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/Documents/Studia/AOC/FruitsClassificationFromHipespectralImages/.venv/lib/python3.12/site-packages/spectral/image.py:86, in ImageArray.__getitem__(self, args)
#      85 try:
# ---> 86     iterator = iter(args)
#      87 except TypeError:
#
# TypeError: 'int' object is not iterable
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 12
#       3     max_length = max(len(f) for f in features)
#       4     return np.array(
#       5         [
#       6             np.pad(f, (0, max_length - len(f)), constant_values=fill_value)
#       7             for f in features
#       8         ]
#       9     )
# ---> 12 X_padded = [pad_features(image["image"]) for image in X1]
#
# Cell In[10], line 3, in pad_features(features, fill_value)
#       1 def pad_features(features, fill_value=0):
#       2     """Pad feature vectors to have the same length."""
# ----> 3     max_length = max(len(f) for f in features)
#       4     return np.array(
#       5         [
#       6             np.pad(f, (0, max_length - len(f)), constant_values=fill_value)
#       7             for f in features
#       8         ]
#       9     )
#
# Cell In[10], line 3, in <genexpr>(.0)
#       1 def pad_features(features, fill_value=0):
#       2     """Pad feature vectors to have the same length."""
# ----> 3     max_length = max(len(f) for f in features)
#       4     return np.array(
#       5         [
#       6             np.pad(f, (0, max_length - len(f)), constant_values=fill_value)
#       7             for f in features
#       8         ]
#       9     )
#
# File ~/Documents/Studia/AOC/FruitsClassificationFromHipespectralImages/.venv/lib/python3.12/site-packages/spectral/image.py:88, in ImageArray.__getitem__(self, args)
#      86     iterator = iter(args)
#      87 except TypeError:
# ---> 88     if isinstance(args, numbers.Number):
#      89         if args == -1:
#      90             updated_args = slice(args, None)
#
# File <frozen abc>:117, in __instancecheck__(cls, instance)
#
# KeyboardInterrupt:

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Example: Process a list of spectral images
X_fft = [fourier_2d_features(image) for image in X_padded]  # Fourier features
y = Y1  # Labels: ripe, unripe, perfect

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X_fft, y, test_size=0.2, random_state=42
)

# Classifier
clf = RandomForestClassifier(n_estimators=100)
clf.fit(X_train, y_train)

# Predictions
y_pred = clf.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 6
#       3 from sklearn.metrics import accuracy_score
#       5 # Example: Process a list of spectral images
# ----> 6 X_fft = [fourier_2d_features(image["image"]) for image in X_padded]  # Fourier features
#       7 y = Y1  # Labels: ripe, unripe, perfect
#       9 # Train-test split
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
import os
import numpy as np
from spectral import envi
import json
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Load JSON data
with open("train_only_labeled.json", "r") as f:
    data = json.load(f)

annotations = data["annotations"]
records = data["records"]
cameras = data["cameras"]
vis_wls = cameras[0]["wavelengths"]
nir_wls = cameras[1]["wavelengths"]

ripeness_mapping = {"unripe": 0, "perfect": 1, "overripe": 2}

X = []
Y = []

# Load hyperspectral images
for annotation in annotations:
    record = next((r for r in records if r["id"] == annotation["record_id"]), None)
    if record:
        header_file = os.path.join("data", record["files"]["header_file"])
        data_file = os.path.join("data", record["files"]["data_file"])
        if os.path.exists(header_file) and os.path.exists(data_file):
            try:
                image = envi.open(header_file, image=data_file)
                X.append({"image": image.load(), "camera": record["camera_type"]})
                Y.append(ripeness_mapping[annotation["ripeness_state"]])
            except Exception as e:
                print(f"Error loading image: {e}")
        else:
            print(f"Missing file: {header_file} or {data_file}")

X = np.array(X, dtype=object)
Y = np.array(Y, dtype=int)
print(f"Loaded dataset: {len(X)} samples.")


# Fourier Features Functions
def fourier_features(image):
    """Compute Fourier Transform magnitudes for each pixel's spectral vector."""
    fft_magnitude = np.abs(np.fft.fft(image, axis=-1))  # FFT along spectral axis
    return fft_magnitude[:, :, : image.shape[-1] // 2]  # Use positive frequencies


def fourier_2d_features(image):
    """Compute 2D Fourier Transform for each spectral channel."""
    fft_features = []
    for i in range(image.shape[-1]):
        channel_fft = np.fft.fft2(image[:, :, i])
        fft_magnitude = np.abs(channel_fft)
        fft_features.append(fft_magnitude.flatten())
    return np.concatenate(fft_features)


def pad_features(features, fill_value=0):
    """Pad feature vectors to have the same length."""
    max_length = max(len(f) for f in features)
    return np.array(
        [
            np.pad(f, (0, max_length - len(f)), constant_values=fill_value)
            for f in features
        ]
    )


# Filter only VIS images
X_vis = []
Y_vis = []

for x, y in zip(X, Y):
    if x["camera"] == "VIS":
        X_vis.append(x["image"])
        Y_vis.append(y)

X_vis = np.array(X_vis, dtype=object)
Y_vis = np.array(Y_vis, dtype=int)
print(f"Filtered VIS dataset: {len(X_vis)} samples.")

# Extract Fourier Features
X_fft = []
for image in X_vis:
    fft_features = fourier_2d_features(image)  # Flattened 2D FFT features
    X_fft.append(fft_features)
# Out:
# Missing file: data/Kiwi/NIR/day_01/kiwi_day_01_03_front.hdr or data/Kiwi/NIR/day_01/kiwi_day_01_03_front.bin
# Missing file: data/Kiwi/VIS/day_01/kiwi_day_01_03_front.hdr or data/Kiwi/VIS/day_01/kiwi_day_01_03_front.bin
# Missing file: data/Kiwi/NIR/day_01/kiwi_day_01_03_back.hdr or data/Kiwi/NIR/day_01/kiwi_day_01_03_back.bin
# Missing file: data/Kiwi/VIS/day_01/kiwi_day_01_03_back.hdr or data/Kiwi/VIS/day_01/kiwi_day_01_03_back.bin
# Missing file: data/Kiwi/NIR/day_01/kiwi_day_01_28_front.hdr or data/Kiwi/NIR/day_01/kiwi_day_01_28_front.bin
# Missing file: data/Kiwi/VIS/day_01/kiwi_day_01_28_front.hdr or data/Kiwi/VIS/day_01/kiwi_day_01_28_front.bin
# Missing file: data/Kiwi/NIR/day_01/kiwi_day_01_28_back.hdr or data/Kiwi/NIR/day_01/kiwi_day_01_28_back.bin
# Missing file: data/Kiwi/VIS/day_01/kiwi_day_01_28_back.hdr or data/Kiwi/VIS/day_01/kiwi_day_01_28_back.bin
# Missing file: data/Kiwi/NIR/day_02/kiwi_day_02_10_front.hdr or data/Kiwi/NIR/day_02/kiwi_day_02_10_front.bin
# Missing file: data/Kiwi/VIS/day_02/kiwi_day_02_10_front.hdr or data/Kiwi/VIS/day_02/kiwi_day_02_10_front.bin
# Missing file: data/Kiwi/NIR/day_02/kiwi_day_02_10_back.hdr or data/Kiwi/NIR/day_02/kiwi_day_02_10_back.bin
# Missing file: data/Kiwi/VIS/day_02/kiwi_day_02_10_back.hdr or data/Kiwi/VIS/day_02/kiwi_day_02_10_back.bin
# Missing file: data/Kiwi/NIR/day_02/kiwi_day_02_15_front.hdr or data/Kiwi/NIR/day_02/kiwi_day_02_15_front.bin
# Missing file: data/Kiwi/VIS/day_02/kiwi_day_02_15_front.hdr or data/Kiwi/VIS/day_02/kiwi_day_02_15_front.bin
# Missing file: data/Kiwi/NIR/day_02/kiwi_day_02_15_back.hdr or data/Kiwi/NIR/day_02/kiwi_day_02_15_back.bin
# Missing file: data/Kiwi/VIS/day_02/kiwi_day_02_15_back.hdr or data/Kiwi/VIS/day_02/kiwi_day_02_15_back.bin
# Missing file: data/Kiwi/NIR/day_02/kiwi_day_02_30_front.hdr or data/Kiwi/NIR/day_02/kiwi_day_02_30_front.bin
# Missing file: data/Kiwi/VIS/day_02/kiwi_day_02_30_front.hdr or data/Kiwi/VIS/day_02/kiwi_day_02_30_front.bin
# Missing file: data/Kiwi/NIR/day_02/kiwi_day_02_30_back.hdr or data/Kiwi/NIR/day_02/kiwi_day_02_30_back.bin
# Missing file: data/Kiwi/VIS/day_02/kiwi_day_02_30_back.hdr or data/Kiwi/VIS/day_02/kiwi_day_02_30_back.bin
# Missing file: data/Kiwi/NIR/day_02/kiwi_day_02_31_front.hdr or data/Kiwi/NIR/day_02/kiwi_day_02_31_front.bin
# Missing file: data/Kiwi/VIS/day_02/kiwi_day_02_31_front.hdr or data/Kiwi/VIS/day_02/kiwi_day_02_31_front.bin
# Missing file: data/Kiwi/NIR/day_02/kiwi_day_02_31_back.hdr or data/Kiwi/NIR/day_02/kiwi_day_02_31_back.bin
# Missing file: data/Kiwi/VIS/day_02/kiwi_day_02_31_back.hdr or data/Kiwi/VIS/day_02/kiwi_day_02_31_back.bin
# Missing file: data/Kiwi/NIR/day_02/kiwi_day_02_33_front.hdr or data/Kiwi/NIR/day_02/kiwi_day_02_33_front.bin
# Missing file: data/Kiwi/VIS/day_02/kiwi_day_02_33_front.hdr or data/Kiwi/VIS/day_02/kiwi_day_02_33_front.bin
# Missing file: data/Kiwi/NIR/day_02/kiwi_day_02_33_back.hdr or data/Kiwi/NIR/day_02/kiwi_day_02_33_back.bin
# Missing file: data/Kiwi/VIS/day_02/kiwi_day_02_33_back.hdr or data/Kiwi/VIS/day_02/kiwi_day_02_33_back.bin
# Missing file: data/Kiwi/VIS/day_03/kiwi_day_03_07_front.hdr or data/Kiwi/VIS/day_03/kiwi_day_03_07_front.bin
# Missing file: data/Kiwi/NIR/day_03/kiwi_day_03_07_back.hdr or data/Kiwi/NIR/day_03/kiwi_day_03_07_back.bin
# Missing file: data/Kiwi/VIS/day_03/kiwi_day_03_07_back.hdr or data/Kiwi/VIS/day_03/kiwi_day_03_07_back.bin
# Missing file: data/Kiwi/NIR/day_03/kiwi_day_03_17_front.hdr or data/Kiwi/NIR/day_03/kiwi_day_03_17_front.bin
# Missing file: data/Kiwi/VIS/day_03/kiwi_day_03_17_front.hdr or data/Kiwi/VIS/day_03/kiwi_day_03_17_front.bin
# Missing file: data/Kiwi/NIR/day_03/kiwi_day_03_17_back.hdr or data/Kiwi/NIR/day_03/kiwi_day_03_17_back.bin
# Missing file: data/Kiwi/NIR/day_03/kiwi_day_03_19_front.hdr or data/Kiwi/NIR/day_03/kiwi_day_03_19_front.bin
# Missing file: data/Kiwi/NIR/day_03/kiwi_day_03_19_back.hdr or data/Kiwi/NIR/day_03/kiwi_day_03_19_back.bin
# Missing file: data/Kiwi/VIS/day_03/kiwi_day_03_19_back.hdr or data/Kiwi/VIS/day_03/kiwi_day_03_19_back.bin
# Missing file: data/Kiwi/NIR/day_03/kiwi_day_03_23_front.hdr or data/Kiwi/NIR/day_03/kiwi_day_03_23_front.bin
# Missing file: data/Kiwi/VIS/day_03/kiwi_day_03_23_front.hdr or data/Kiwi/VIS/day_03/kiwi_day_03_23_front.bin
# Missing file: data/Kiwi/NIR/day_03/kiwi_day_03_23_back.hdr or data/Kiwi/NIR/day_03/kiwi_day_03_23_back.bin
# Missing file: data/Kiwi/NIR/day_03/kiwi_day_03_39_front.hdr or data/Kiwi/NIR/day_03/kiwi_day_03_39_front.bin
# Missing file: data/Kiwi/NIR/day_03/kiwi_day_03_39_back.hdr or data/Kiwi/NIR/day_03/kiwi_day_03_39_back.bin
# Missing file: data/Kiwi/VIS/day_03/kiwi_day_03_39_back.hdr or data/Kiwi/VIS/day_03/kiwi_day_03_39_back.bin
# Missing file: data/Kiwi/NIR/day_04/kiwi_day_04_12_front.hdr or data/Kiwi/NIR/day_04/kiwi_day_04_12_front.bin
# Missing file: data/Kiwi/VIS/day_04/kiwi_day_04_12_front.hdr or data/Kiwi/VIS/day_04/kiwi_day_04_12_front.bin
# Missing file: data/Kiwi/NIR/day_04/kiwi_day_04_13_front.hdr or data/Kiwi/NIR/day_04/kiwi_day_04_13_front.bin
# Missing file: data/Kiwi/VIS/day_04/kiwi_day_04_18_front.hdr or data/Kiwi/VIS/day_04/kiwi_day_04_18_front.bin
# Missing file: data/Kiwi/NIR/day_04/kiwi_day_04_18_back.hdr or data/Kiwi/NIR/day_04/kiwi_day_04_18_back.bin
# Missing file: data/Kiwi/NIR/day_04/kiwi_day_04_21_front.hdr or data/Kiwi/NIR/day_04/kiwi_day_04_21_front.bin
# Missing file: data/Kiwi/VIS/day_04/kiwi_day_04_21_front.hdr or data/Kiwi/VIS/day_04/kiwi_day_04_21_front.bin
# Missing file: data/Kiwi/NIR/day_04/kiwi_day_04_21_back.hdr or data/Kiwi/NIR/day_04/kiwi_day_04_21_back.bin
# Missing file: data/Kiwi/VIS/day_04/kiwi_day_04_21_back.hdr or data/Kiwi/VIS/day_04/kiwi_day_04_21_back.bin
# Missing file: data/Kiwi/NIR/day_04/kiwi_day_04_22_front.hdr or data/Kiwi/NIR/day_04/kiwi_day_04_22_front.bin
# Missing file: data/Kiwi/VIS/day_04/kiwi_day_04_22_front.hdr or data/Kiwi/VIS/day_04/kiwi_day_04_22_front.bin
# Missing file: data/Kiwi/NIR/day_04/kiwi_day_04_22_back.hdr or data/Kiwi/NIR/day_04/kiwi_day_04_22_back.bin
# Missing file: data/Kiwi/NIR/day_04/kiwi_day_04_29_front.hdr or data/Kiwi/NIR/day_04/kiwi_day_04_29_front.bin
# Missing file: data/Kiwi/NIR/day_04/kiwi_day_04_29_back.hdr or data/Kiwi/NIR/day_04/kiwi_day_04_29_back.bin
# Missing file: data/Kiwi/VIS/day_04/kiwi_day_04_29_back.hdr or data/Kiwi/VIS/day_04/kiwi_day_04_29_back.bin
# Missing file: data/Kiwi/VIS/day_05/kiwi_day_05_02_front.hdr or data/Kiwi/VIS/day_05/kiwi_day_05_02_front.bin
# Missing file: data/Kiwi/NIR/day_05/kiwi_day_05_02_back.hdr or data/Kiwi/NIR/day_05/kiwi_day_05_02_back.bin
# Missing file: data/Kiwi/VIS/day_05/kiwi_day_05_02_back.hdr or data/Kiwi/VIS/day_05/kiwi_day_05_02_back.bin
# Missing file: data/Kiwi/NIR/day_05/kiwi_day_05_05_front.hdr or data/Kiwi/NIR/day_05/kiwi_day_05_05_front.bin
# Missing file: data/Kiwi/NIR/day_05/kiwi_day_05_05_back.hdr or data/Kiwi/NIR/day_05/kiwi_day_05_05_back.bin
# Missing file: data/Kiwi/VIS/day_05/kiwi_day_05_05_back.hdr or data/Kiwi/VIS/day_05/kiwi_day_05_05_back.bin
# Missing file: data/Kiwi/NIR/day_05/kiwi_day_05_08_front.hdr or data/Kiwi/NIR/day_05/kiwi_day_05_08_front.bin
# Missing file: data/Kiwi/VIS/day_05/kiwi_day_05_08_front.hdr or data/Kiwi/VIS/day_05/kiwi_day_05_08_front.bin
# Missing file: data/Kiwi/VIS/day_05/kiwi_day_05_08_back.hdr or data/Kiwi/VIS/day_05/kiwi_day_05_08_back.bin
# Missing file: data/Kiwi/VIS/day_05/kiwi_day_05_32_front.hdr or data/Kiwi/VIS/day_05/kiwi_day_05_32_front.bin
# Missing file: data/Kiwi/NIR/day_05/kiwi_day_05_37_front.hdr or data/Kiwi/NIR/day_05/kiwi_day_05_37_front.bin
# Missing file: data/Kiwi/VIS/day_05/kiwi_day_05_37_front.hdr or data/Kiwi/VIS/day_05/kiwi_day_05_37_front.bin
# Missing file: data/Kiwi/NIR/day_05/kiwi_day_05_37_back.hdr or data/Kiwi/NIR/day_05/kiwi_day_05_37_back.bin
# Missing file: data/Kiwi/VIS/day_05/kiwi_day_05_37_back.hdr or data/Kiwi/VIS/day_05/kiwi_day_05_37_back.bin
# Missing file: data/Kiwi/NIR/day_06/kiwi_day_06_01_front.hdr or data/Kiwi/NIR/day_06/kiwi_day_06_01_front.bin
# Missing file: data/Kiwi/VIS/day_06/kiwi_day_06_01_front.hdr or data/Kiwi/VIS/day_06/kiwi_day_06_01_front.bin
# Missing file: data/Kiwi/VIS/day_06/kiwi_day_06_01_back.hdr or data/Kiwi/VIS/day_06/kiwi_day_06_01_back.bin
# Missing file: data/Kiwi/VIS/day_06/kiwi_day_06_11_front.hdr or data/Kiwi/VIS/day_06/kiwi_day_06_11_front.bin
# Missing file: data/Kiwi/NIR/day_06/kiwi_day_06_11_back.hdr or data/Kiwi/NIR/day_06/kiwi_day_06_11_back.bin
# Missing file: data/Kiwi/NIR/day_06/kiwi_day_06_20_front.hdr or data/Kiwi/NIR/day_06/kiwi_day_06_20_front.bin
# Missing file: data/Kiwi/VIS/day_06/kiwi_day_06_20_front.hdr or data/Kiwi/VIS/day_06/kiwi_day_06_20_front.bin
# Missing file: data/Kiwi/NIR/day_06/kiwi_day_06_20_back.hdr or data/Kiwi/NIR/day_06/kiwi_day_06_20_back.bin
# Missing file: data/Kiwi/VIS/day_06/kiwi_day_06_35_front.hdr or data/Kiwi/VIS/day_06/kiwi_day_06_35_front.bin
# Missing file: data/Kiwi/NIR/day_06/kiwi_day_06_35_back.hdr or data/Kiwi/NIR/day_06/kiwi_day_06_35_back.bin
# Missing file: data/Kiwi/VIS/day_06/kiwi_day_06_35_back.hdr or data/Kiwi/VIS/day_06/kiwi_day_06_35_back.bin
# Missing file: data/Kiwi/NIR/day_06/kiwi_day_06_36_front.hdr or data/Kiwi/NIR/day_06/kiwi_day_06_36_front.bin
# Missing file: data/Kiwi/NIR/day_06/kiwi_day_06_36_back.hdr or data/Kiwi/NIR/day_06/kiwi_day_06_36_back.bin
# Missing file: data/Kiwi/VIS/day_06/kiwi_day_06_36_back.hdr or data/Kiwi/VIS/day_06/kiwi_day_06_36_back.bin
# Missing file: data/Kiwi/NIR/day_06/kiwi_day_06_38_front.hdr or data/Kiwi/NIR/day_06/kiwi_day_06_38_front.bin
# Missing file: data/Kiwi/NIR/day_06/kiwi_day_06_38_back.hdr or data/Kiwi/NIR/day_06/kiwi_day_06_38_back.bin
# Missing file: data/Kiwi/VIS/day_06/kiwi_day_06_38_back.hdr or data/Kiwi/VIS/day_06/kiwi_day_06_38_back.bin
# Missing file: data/Kiwi/NIR/day_07/kiwi_day_07_06_front.hdr or data/Kiwi/NIR/day_07/kiwi_day_07_06_front.bin
# Missing file: data/Kiwi/VIS/day_07/kiwi_day_07_06_front.hdr or data/Kiwi/VIS/day_07/kiwi_day_07_06_front.bin
# Missing file: data/Kiwi/NIR/day_07/kiwi_day_07_06_back.hdr or data/Kiwi/NIR/day_07/kiwi_day_07_06_back.bin
# Missing file: data/Kiwi/VIS/day_07/kiwi_day_07_06_back.hdr or data/Kiwi/VIS/day_07/kiwi_day_07_06_back.bin
# Missing file: data/Kiwi/NIR/day_07/kiwi_day_07_09_front.hdr or data/Kiwi/NIR/day_07/kiwi_day_07_09_front.bin
# Missing file: data/Kiwi/VIS/day_07/kiwi_day_07_09_front.hdr or data/Kiwi/VIS/day_07/kiwi_day_07_09_front.bin
# Missing file: data/Kiwi/NIR/day_07/kiwi_day_07_09_back.hdr or data/Kiwi/NIR/day_07/kiwi_day_07_09_back.bin
# Missing file: data/Kiwi/VIS/day_07/kiwi_day_07_09_back.hdr or data/Kiwi/VIS/day_07/kiwi_day_07_09_back.bin
# Missing file: data/Kiwi/NIR/day_07/kiwi_day_07_14_front.hdr or data/Kiwi/NIR/day_07/kiwi_day_07_14_front.bin
# Missing file: data/Kiwi/VIS/day_07/kiwi_day_07_14_front.hdr or data/Kiwi/VIS/day_07/kiwi_day_07_14_front.bin
# Missing file: data/Kiwi/NIR/day_07/kiwi_day_07_14_back.hdr or data/Kiwi/NIR/day_07/kiwi_day_07_14_back.bin
# Missing file: data/Kiwi/VIS/day_07/kiwi_day_07_14_back.hdr or data/Kiwi/VIS/day_07/kiwi_day_07_14_back.bin
# Missing file: data/Kiwi/VIS/day_07/kiwi_day_07_16_front.hdr or data/Kiwi/VIS/day_07/kiwi_day_07_16_front.bin
# Missing file: data/Kiwi/NIR/day_07/kiwi_day_07_16_back.hdr or data/Kiwi/NIR/day_07/kiwi_day_07_16_back.bin
# Missing file: data/Kiwi/NIR/day_07/kiwi_day_07_24_front.hdr or data/Kiwi/NIR/day_07/kiwi_day_07_24_front.bin
# Missing file: data/Kiwi/VIS/day_07/kiwi_day_07_24_back.hdr or data/Kiwi/VIS/day_07/kiwi_day_07_24_back.bin
# Missing file: data/Kiwi/NIR/day_08/kiwi_day_08_04_front.hdr or data/Kiwi/NIR/day_08/kiwi_day_08_04_front.bin
# Missing file: data/Kiwi/VIS/day_08/kiwi_day_08_04_front.hdr or data/Kiwi/VIS/day_08/kiwi_day_08_04_front.bin
# Missing file: data/Kiwi/VIS/day_08/kiwi_day_08_04_back.hdr or data/Kiwi/VIS/day_08/kiwi_day_08_04_back.bin
# Missing file: data/Kiwi/NIR/day_09/kiwi_day_09_25_front.hdr or data/Kiwi/NIR/day_09/kiwi_day_09_25_front.bin
# Missing file: data/Kiwi/VIS/day_09/kiwi_day_09_25_front.hdr or data/Kiwi/VIS/day_09/kiwi_day_09_25_front.bin
# Missing file: data/Kiwi/NIR/day_09/kiwi_day_09_25_back.hdr or data/Kiwi/NIR/day_09/kiwi_day_09_25_back.bin
# Missing file: data/Kiwi/VIS/day_09/kiwi_day_09_25_back.hdr or data/Kiwi/VIS/day_09/kiwi_day_09_25_back.bin
# Missing file: data/Kiwi/VIS/day_10/kiwi_day_10_27_front.hdr or data/Kiwi/VIS/day_10/kiwi_day_10_27_front.bin
# Missing file: data/Kiwi/VIS/day_10/kiwi_day_10_27_back.hdr or data/Kiwi/VIS/day_10/kiwi_day_10_27_back.bin
# Missing file: data/Kiwi/VIS/day_m2_01/kiwi_day_m2_01_53_front.hdr or data/Kiwi/VIS/day_m2_01/kiwi_day_m2_01_53_front.bin
# Missing file: data/Kiwi/VIS/day_m2_01/kiwi_day_m2_01_53_back.hdr or data/Kiwi/VIS/day_m2_01/kiwi_day_m2_01_53_back.bin
# Missing file: data/Kiwi/VIS/day_m2_01/kiwi_day_m2_01_71_front.hdr or data/Kiwi/VIS/day_m2_01/kiwi_day_m2_01_71_front.bin
# Missing file: data/Kiwi/VIS/day_m2_02/kiwi_day_m2_02_43_front.hdr or data/Kiwi/VIS/day_m2_02/kiwi_day_m2_02_43_front.bin
# Missing file: data/Kiwi/VIS/day_m2_02/kiwi_day_m2_02_43_back.hdr or data/Kiwi/VIS/day_m2_02/kiwi_day_m2_02_43_back.bin
# Missing file: data/Kiwi/VIS/day_m2_02/kiwi_day_m2_02_75_front.hdr or data/Kiwi/VIS/day_m2_02/kiwi_day_m2_02_75_front.bin
# Missing file: data/Kiwi/VIS/day_m2_02/kiwi_day_m2_02_75_back.hdr or data/Kiwi/VIS/day_m2_02/kiwi_day_m2_02_75_back.bin
# Missing file: data/Kiwi/VIS/day_m2_02/kiwi_day_m2_02_85_front.hdr or data/Kiwi/VIS/day_m2_02/kiwi_day_m2_02_85_front.bin
# Missing file: data/Kiwi/VIS/day_m2_02/kiwi_day_m2_02_85_back.hdr or data/Kiwi/VIS/day_m2_02/kiwi_day_m2_02_85_back.bin
# Missing file: data/Kiwi/VIS/day_m2_03/kiwi_day_m2_03_40_front.hdr or data/Kiwi/VIS/day_m2_03/kiwi_day_m2_03_40_front.bin
# Missing file: data/Kiwi/VIS/day_m2_03/kiwi_day_m2_03_40_back.hdr or data/Kiwi/VIS/day_m2_03/kiwi_day_m2_03_40_back.bin
# Missing file: data/Kiwi/VIS/day_m2_03/kiwi_day_m2_03_52_front.hdr or data/Kiwi/VIS/day_m2_03/kiwi_day_m2_03_52_front.bin
# Missing file: data/Kiwi/VIS/day_m2_03/kiwi_day_m2_03_70_front.hdr or data/Kiwi/VIS/day_m2_03/kiwi_day_m2_03_70_front.bin
# Missing file: data/Kiwi/VIS/day_m2_03/kiwi_day_m2_03_70_back.hdr or data/Kiwi/VIS/day_m2_03/kiwi_day_m2_03_70_back.bin
# Missing file: data/Kiwi/VIS/day_m2_03/kiwi_day_m2_03_75_front.hdr or data/Kiwi/VIS/day_m2_03/kiwi_day_m2_03_75_front.bin
# Missing file: data/Kiwi/VIS/day_m2_03/kiwi_day_m2_03_75_back.hdr or data/Kiwi/VIS/day_m2_03/kiwi_day_m2_03_75_back.bin
# Missing file: data/Kiwi/VIS/day_m2_03/kiwi_day_m2_03_77_front.hdr or data/Kiwi/VIS/day_m2_03/kiwi_day_m2_03_77_front.bin
# Missing file: data/Kiwi/VIS/day_m2_03/kiwi_day_m2_03_77_back.hdr or data/Kiwi/VIS/day_m2_03/kiwi_day_m2_03_77_back.bin
# Missing file: data/Kiwi/VIS/day_m2_04/kiwi_day_m2_04_61_front.hdr or data/Kiwi/VIS/day_m2_04/kiwi_day_m2_04_61_front.bin
# Missing file: data/Kiwi/VIS/day_m2_04/kiwi_day_m2_04_61_back.hdr or data/Kiwi/VIS/day_m2_04/kiwi_day_m2_04_61_back.bin
# Missing file: data/Kiwi/VIS/day_m2_04/kiwi_day_m2_04_72_front.hdr or data/Kiwi/VIS/day_m2_04/kiwi_day_m2_04_72_front.bin
# Missing file: data/Kiwi/VIS/day_m2_04/kiwi_day_m2_04_72_back.hdr or data/Kiwi/VIS/day_m2_04/kiwi_day_m2_04_72_back.bin
# Missing file: data/Kiwi/VIS/day_m2_04/kiwi_day_m2_04_75_front.hdr or data/Kiwi/VIS/day_m2_04/kiwi_day_m2_04_75_front.bin
# Missing file: data/Kiwi/VIS/day_m2_04/kiwi_day_m2_04_75_back.hdr or data/Kiwi/VIS/day_m2_04/kiwi_day_m2_04_75_back.bin
# Missing file: data/Kiwi/VIS/day_m2_04/kiwi_day_m2_04_81_front.hdr or data/Kiwi/VIS/day_m2_04/kiwi_day_m2_04_81_front.bin
# Missing file: data/Kiwi/VIS/day_m2_04/kiwi_day_m2_04_81_back.hdr or data/Kiwi/VIS/day_m2_04/kiwi_day_m2_04_81_back.bin
# Missing file: data/Kiwi/VIS/day_m2_04/kiwi_day_m2_04_87_front.hdr or data/Kiwi/VIS/day_m2_04/kiwi_day_m2_04_87_front.bin
# Missing file: data/Kiwi/VIS/day_m2_05/kiwi_day_m2_05_51_back.hdr or data/Kiwi/VIS/day_m2_05/kiwi_day_m2_05_51_back.bin
# Missing file: data/Kiwi/VIS/day_m2_05/kiwi_day_m2_05_65_front.hdr or data/Kiwi/VIS/day_m2_05/kiwi_day_m2_05_65_front.bin
# Missing file: data/Kiwi/VIS/day_m2_05/kiwi_day_m2_05_65_back.hdr or data/Kiwi/VIS/day_m2_05/kiwi_day_m2_05_65_back.bin
# Missing file: data/Kiwi/VIS/day_m2_05/kiwi_day_m2_05_74_back.hdr or data/Kiwi/VIS/day_m2_05/kiwi_day_m2_05_74_back.bin
# Missing file: data/Kiwi/VIS/day_m2_05/kiwi_day_m2_05_75_front.hdr or data/Kiwi/VIS/day_m2_05/kiwi_day_m2_05_75_front.bin
# Missing file: data/Kiwi/VIS/day_m2_05/kiwi_day_m2_05_75_back.hdr or data/Kiwi/VIS/day_m2_05/kiwi_day_m2_05_75_back.bin
# Missing file: data/Kiwi/VIS/day_m2_06/kiwi_day_m2_06_78_front.hdr or data/Kiwi/VIS/day_m2_06/kiwi_day_m2_06_78_front.bin
# Missing file: data/Kiwi/VIS/day_m2_06/kiwi_day_m2_06_78_back.hdr or data/Kiwi/VIS/day_m2_06/kiwi_day_m2_06_78_back.bin
# Missing file: data/Kiwi/VIS/day_m2_06/kiwi_day_m2_06_79_front.hdr or data/Kiwi/VIS/day_m2_06/kiwi_day_m2_06_79_front.bin
# Missing file: data/Kiwi/VIS/day_m2_06/kiwi_day_m2_06_79_back.hdr or data/Kiwi/VIS/day_m2_06/kiwi_day_m2_06_79_back.bin
# Missing file: data/Kiwi/VIS/day_m2_06/kiwi_day_m2_06_84_front.hdr or data/Kiwi/VIS/day_m2_06/kiwi_day_m2_06_84_front.bin
# Missing file: data/Kiwi/VIS/day_m2_06/kiwi_day_m2_06_84_back.hdr or data/Kiwi/VIS/day_m2_06/kiwi_day_m2_06_84_back.bin
# Missing file: data/Kiwi/VIS/day_m2_06/kiwi_day_m2_06_86_front.hdr or data/Kiwi/VIS/day_m2_06/kiwi_day_m2_06_86_front.bin
# Missing file: data/Kiwi/VIS/day_m2_06/kiwi_day_m2_06_86_back.hdr or data/Kiwi/VIS/day_m2_06/kiwi_day_m2_06_86_back.bin
# Missing file: data/Kiwi/VIS/day_m2_07/kiwi_day_m2_07_49_front.hdr or data/Kiwi/VIS/day_m2_07/kiwi_day_m2_07_49_front.bin
# Missing file: data/Kiwi/VIS/day_m2_07/kiwi_day_m2_07_56_front.hdr or data/Kiwi/VIS/day_m2_07/kiwi_day_m2_07_56_front.bin
# Missing file: data/Kiwi/VIS/day_m2_07/kiwi_day_m2_07_56_back.hdr or data/Kiwi/VIS/day_m2_07/kiwi_day_m2_07_56_back.bin
# Missing file: data/Kiwi/VIS/day_m2_07/kiwi_day_m2_07_60_front.hdr or data/Kiwi/VIS/day_m2_07/kiwi_day_m2_07_60_front.bin
# Missing file: data/Kiwi/VIS/day_m2_07/kiwi_day_m2_07_83_front.hdr or data/Kiwi/VIS/day_m2_07/kiwi_day_m2_07_83_front.bin
# Missing file: data/Kiwi/VIS/day_m2_07/kiwi_day_m2_07_83_back.hdr or data/Kiwi/VIS/day_m2_07/kiwi_day_m2_07_83_back.bin
# Missing file: data/Kiwi/VIS/day_m2_08/kiwi_day_m2_08_54_front.hdr or data/Kiwi/VIS/day_m2_08/kiwi_day_m2_08_54_front.bin
# Missing file: data/Kiwi/VIS/day_m2_08/kiwi_day_m2_08_63_back.hdr or data/Kiwi/VIS/day_m2_08/kiwi_day_m2_08_63_back.bin
# Missing file: data/Kiwi/VIS/day_m2_08/kiwi_day_m2_08_82_front.hdr or data/Kiwi/VIS/day_m2_08/kiwi_day_m2_08_82_front.bin
# Missing file: data/Kiwi/VIS/day_m2_08/kiwi_day_m2_08_82_back.hdr or data/Kiwi/VIS/day_m2_08/kiwi_day_m2_08_82_back.bin
# Missing file: data/Kiwi/VIS/day_m2_09/kiwi_day_m2_09_47_front.hdr or data/Kiwi/VIS/day_m2_09/kiwi_day_m2_09_47_front.bin
# Missing file: data/Kiwi/VIS/day_m2_09/kiwi_day_m2_09_47_back.hdr or data/Kiwi/VIS/day_m2_09/kiwi_day_m2_09_47_back.bin
# Missing file: data/Kiwi/VIS/day_m2_09/kiwi_day_m2_09_59_front.hdr or data/Kiwi/VIS/day_m2_09/kiwi_day_m2_09_59_front.bin
# Missing file: data/Kiwi/VIS/day_m2_09/kiwi_day_m2_09_59_back.hdr or data/Kiwi/VIS/day_m2_09/kiwi_day_m2_09_59_back.bin
# Missing file: data/Kiwi/VIS/day_m2_09/kiwi_day_m2_09_80_front.hdr or data/Kiwi/VIS/day_m2_09/kiwi_day_m2_09_80_front.bin
# Missing file: data/Kiwi/VIS/day_m2_09/kiwi_day_m2_09_80_back.hdr or data/Kiwi/VIS/day_m2_09/kiwi_day_m2_09_80_back.bin
# Missing file: data/Kiwi/VIS/day_m2_10/kiwi_day_m2_10_46_back.hdr or data/Kiwi/VIS/day_m2_10/kiwi_day_m2_10_46_back.bin
# Missing file: data/Kiwi/VIS/day_m2_10/kiwi_day_m2_10_55_front.hdr or data/Kiwi/VIS/day_m2_10/kiwi_day_m2_10_55_front.bin
# Missing file: data/Kiwi/VIS/day_m2_10/kiwi_day_m2_10_58_front.hdr or data/Kiwi/VIS/day_m2_10/kiwi_day_m2_10_58_front.bin
# Missing file: data/Kiwi/VIS/day_m2_10/kiwi_day_m2_10_58_back.hdr or data/Kiwi/VIS/day_m2_10/kiwi_day_m2_10_58_back.bin
# Missing file: data/Kiwi/VIS/day_m2_11/kiwi_day_m2_11_66_front.hdr or data/Kiwi/VIS/day_m2_11/kiwi_day_m2_11_66_front.bin
# Missing file: data/Kiwi/VIS/day_m2_11/kiwi_day_m2_11_66_back.hdr or data/Kiwi/VIS/day_m2_11/kiwi_day_m2_11_66_back.bin
# Missing file: data/Kiwi/VIS/day_m2_11/kiwi_day_m2_11_68_front.hdr or data/Kiwi/VIS/day_m2_11/kiwi_day_m2_11_68_front.bin
# Missing file: data/Kiwi/VIS/day_m2_11/kiwi_day_m2_11_73_front.hdr or data/Kiwi/VIS/day_m2_11/kiwi_day_m2_11_73_front.bin
# Missing file: data/Kiwi/VIS/day_m2_12/kiwi_day_m2_12_76_front.hdr or data/Kiwi/VIS/day_m2_12/kiwi_day_m2_12_76_front.bin
# Missing file: data/Kiwi/VIS/day_m2_13/kiwi_day_m2_13_42_front.hdr or data/Kiwi/VIS/day_m2_13/kiwi_day_m2_13_42_front.bin
# Missing file: data/Kiwi/VIS/day_m2_13/kiwi_day_m2_13_42_back.hdr or data/Kiwi/VIS/day_m2_13/kiwi_day_m2_13_42_back.bin
# Missing file: data/Kiwi/VIS/day_m2_13/kiwi_day_m2_13_64_front.hdr or data/Kiwi/VIS/day_m2_13/kiwi_day_m2_13_64_front.bin
# Missing file: data/Kiwi/VIS/day_m2_13/kiwi_day_m2_13_64_back.hdr or data/Kiwi/VIS/day_m2_13/kiwi_day_m2_13_64_back.bin
# Missing file: data/Kiwi/VIS/day_m2_14/kiwi_day_m2_14_41_back.hdr or data/Kiwi/VIS/day_m2_14/kiwi_day_m2_14_41_back.bin
# Missing file: data/Kiwi/VIS/day_m2_14/kiwi_day_m2_14_48_front.hdr or data/Kiwi/VIS/day_m2_14/kiwi_day_m2_14_48_front.bin
# Missing file: data/Kiwi/VIS/day_m2_14/kiwi_day_m2_14_48_back.hdr or data/Kiwi/VIS/day_m2_14/kiwi_day_m2_14_48_back.bin
# Missing file: data/Kiwi/VIS/day_m2_14/kiwi_day_m2_14_67_front.hdr or data/Kiwi/VIS/day_m2_14/kiwi_day_m2_14_67_front.bin
# Missing file: data/Kiwi/VIS/day_m2_14/kiwi_day_m2_14_67_back.hdr or data/Kiwi/VIS/day_m2_14/kiwi_day_m2_14_67_back.bin
# Missing file: data/Kiwi/VIS/day_m2_15/kiwi_day_m2_15_48_back.hdr or data/Kiwi/VIS/day_m2_15/kiwi_day_m2_15_48_back.bin
# Missing file: data/Kiwi/VIS/day_m2_15/kiwi_day_m2_15_69_front.hdr or data/Kiwi/VIS/day_m2_15/kiwi_day_m2_15_69_front.bin
# Missing file: data/Kiwi/VIS/day_m2_16/kiwi_day_m2_16_48_front.hdr or data/Kiwi/VIS/day_m2_16/kiwi_day_m2_16_48_front.bin
# Missing file: data/Kiwi/VIS/day_m2_16/kiwi_day_m2_16_57_back.hdr or data/Kiwi/VIS/day_m2_16/kiwi_day_m2_16_57_back.bin
# Missing file: data/Kiwi/VIS/day_m2_17/kiwi_day_m2_17_44_front.hdr or data/Kiwi/VIS/day_m2_17/kiwi_day_m2_17_44_front.bin
# Missing file: data/Kiwi/VIS/day_m2_17/kiwi_day_m2_17_44_back.hdr or data/Kiwi/VIS/day_m2_17/kiwi_day_m2_17_44_back.bin
# Missing file: data/Kiwi/VIS/day_m2_17/kiwi_day_m2_17_48_back.hdr or data/Kiwi/VIS/day_m2_17/kiwi_day_m2_17_48_back.bin
# Loaded dataset: 132 samples.
# Filtered VIS dataset: 92 samples.

# %%
X_fft = [fourier_2d_features(image) for image in X_vis]
X_fft_padded = pad_features(X_fft)
Y_vis = np.array(Y_vis)

# %%
from imblearn.over_sampling import RandomOverSampler
from collections import Counter

# Balance the dataset
ros = RandomOverSampler(random_state=42)
X_resampled, Y_resampled = ros.fit_resample(X_fft_padded, Y_vis)

print("Original class distribution:", Counter(Y_vis))
print("Resampled class distribution:", Counter(Y_resampled))

# Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(
    X_resampled, Y_resampled, test_size=0.2, random_state=42
)

# Train RandomForest Classifier
clf = RandomForestClassifier(n_estimators=100, random_state=42)
clf.fit(X_train, y_train)

# Predict and Evaluate
y_pred = clf.predict(X_test)
print(y_pred)
print("Accuracy:", accuracy_score(y_test, y_pred))

# %%
from collections import Counter

print("Class distribution in VIS dataset:", Counter(Y_vis))
# Out:
# Class distribution in VIS dataset: Counter({np.int64(1): 50, np.int64(2): 26, np.int64(0): 16})
