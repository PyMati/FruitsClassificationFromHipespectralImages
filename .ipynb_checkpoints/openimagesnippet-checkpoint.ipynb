# %%
import spectral
import spectral.io.envi as envi
import os

# %%
oobx_dir = f'../fruits_dataset'
fruits = f'{oobx_dir}/Mango/VIS/day_1_m3/mango_day_1_m3_01_back'

img = envi.open(fruits + '.hdr', image=fruits + '.bin')
img
# Out:
# 	Data Source:   './../fruits_dataset/Mango/VIS/day_1_m3/mango_day_1_m3_01_back.bin'
# 	# Rows:             64
# 	# Samples:          64
# 	# Bands:           224
# 	Interleave:        BIP
# 	Quantization:  32 bits
# 	Data format:   float32

# %%
spectral.imshow(img)
# Out:
# ImageView object:
#   Display bands       :  [0, 112, 223]
#   Interpolation       :  <default>
#   RGB data limits     :
#     R: [-0.05103709548711777, 0.44330891966819763]
#     G: [-0.006623237393796444, 0.31127849221229553]
#     B: [-0.016016412526369095, 0.6931084394454956]

# %%
ls ..
# Out:
# FruitsClassificationFromHipespectralImages/  fruits_dataset/  README.txt

# %%
pwd
# Out:
# '/home/r/Desktop/projekty/SIiUM/Analiza obrazów cyfrowych/AoC_projekt/FruitsClassificationFromHipespectralImages'

# %%
os.getcwd()
# Out:
# '/home/r/Desktop/projekty/SIiUM/Analiza obrazów cyfrowych/AoC_projekt/FruitsClassificationFromHipespectralImages'
